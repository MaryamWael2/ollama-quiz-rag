# %%
# Install requirements from requirements.txt
# !pip install -r "../requirements.txt"
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 1)) (1.0.8)
# Collecting langchain-community (from -r ../requirements.txt (line 2))
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-text-splitters (from -r ../requirements.txt (line 3))
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting fastembed (from -r ../requirements.txt (line 4))
#   Downloading fastembed-0.7.3-py3-none-any.whl.metadata (10 kB)
# Collecting chromadb (from -r ../requirements.txt (line 5))
#   Downloading chromadb-1.3.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Collecting langchain-ollama (from -r ../requirements.txt (line 6))
#   Downloading langchain_ollama-1.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-chroma (from -r ../requirements.txt (line 7))
#   Downloading langchain_chroma-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-classic (from -r ../requirements.txt (line 8))
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting ollama (from -r ../requirements.txt (line 9))
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r ../requirements.txt (line 11)) (1.6.1)
# Collecting tk (from -r ../requirements.txt (line 12))
#   Downloading tk-0.1.0-py3-none-any.whl.metadata (693 bytes)
# Collecting unstructured (from -r ../requirements.txt (line 13))
#   Downloading unstructured-0.18.21-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from langchain->-r ../requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain->-r ../requirements.txt (line 1)) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r ../requirements.txt (line 1)) (2.11.10)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (2.0.44)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community->-r ../requirements.txt (line 2))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community->-r ../requirements.txt (line 2))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (0.4.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r ../requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.12/dist-packages (from fastembed->-r ../requirements.txt (line 4)) (0.36.0)
# Collecting loguru<0.8.0,>=0.7.2 (from fastembed->-r ../requirements.txt (line 4))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting mmh3<6.0.0,>=4.1.0 (from fastembed->-r ../requirements.txt (line 4))
#   Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (14 kB)
# Collecting onnxruntime!=1.20.0,>=1.17.0 (from fastembed->-r ../requirements.txt (line 4))
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from fastembed->-r ../requirements.txt (line 4)) (11.3.0)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed->-r ../requirements.txt (line 4))
#   Downloading py_rust_stemmers-0.1.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from fastembed->-r ../requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.12/dist-packages (from fastembed->-r ../requirements.txt (line 4)) (4.67.1)
# Collecting build>=1.0.3 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading pybase64-1.4.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (0.38.0)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (1.37.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (1.37.0)
# Collecting pypika>=0.48.9 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (0.20.0)
# Collecting kubernetes>=28.1.0 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r ../requirements.txt (line 5)) (4.25.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r ../requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r ../requirements.txt (line 11)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r ../requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (3.4.4)
# Collecting filetype (from unstructured->-r ../requirements.txt (line 13))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured->-r ../requirements.txt (line 13))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (6.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (4.13.5)
# Collecting emoji (from unstructured->-r ../requirements.txt (line 13))
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting python-iso639 (from unstructured->-r ../requirements.txt (line 13))
#   Downloading python_iso639-2025.11.16-py3-none-any.whl.metadata (15 kB)
# Collecting langdetect (from unstructured->-r ../requirements.txt (line 13))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured->-r ../requirements.txt (line 13))
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured->-r ../requirements.txt (line 13))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured->-r ../requirements.txt (line 13))
#   Downloading unstructured_client-0.42.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (2.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (5.9.5)
# Collecting python-oxmsg (from unstructured->-r ../requirements.txt (line 13))
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from unstructured->-r ../requirements.txt (line 13)) (1.1)
# Collecting onnx>=1.17.0 (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Collecting pdf2image (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pdfminer.six (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Collecting pikepdf (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pikepdf-10.0.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting pi_heif (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pypdf (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pypdf-6.4.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting google-cloud-vision (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading google_cloud_vision-3.11.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting effdet (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference>=1.1.1 (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading unstructured_inference-1.1.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r ../requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 5)) (25.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->-r ../requirements.txt (line 5))
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r ../requirements.txt (line 2))
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r ../requirements.txt (line 2))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed->-r ../requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed->-r ../requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed->-r ../requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 5)) (0.29.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (2.0.0)
# Collecting urllib3<2.4.0,>=1.24.2 (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5))
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain->-r ../requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 1)) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r ../requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r ../requirements.txt (line 2)) (0.25.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17.0->unstructured[pdf]->-r ../requirements.txt (line 14)) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17.0->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.5.4)
# Collecting coloredlogs (from onnxruntime!=1.20.0,>=1.17.0->fastembed->-r ../requirements.txt (line 4))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed->-r ../requirements.txt (line 4)) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime!=1.20.0,>=1.17.0->fastembed->-r ../requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk>=1.2.0->chromadb->-r ../requirements.txt (line 5))
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->-r ../requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->-r ../requirements.txt (line 2)) (3.2.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.0.20)
# Requirement already satisfied: opencv-python>=4.12 in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.9.0+cu126)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.0.22)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (4.57.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.2.2)
# Collecting pypdfium2 (from unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading pypdfium2-5.1.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.6 MB/s eta 0:00:00
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5))
#   Downloading httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5))
#   Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5))
#   Downloading watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->unstructured->-r ../requirements.txt (line 13)) (2.8)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.24.0+cu126)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.0.10)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.12/dist-packages (from effdet->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-vision->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.26.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured->-r ../requirements.txt (line 13)) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured->-r ../requirements.txt (line 13)) (2025.11.3)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six->unstructured[pdf]->-r ../requirements.txt (line 14)) (43.0.3)
# Collecting Deprecated (from pikepdf->unstructured[pdf]->-r ../requirements.txt (line 14))
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting olefile (from python-oxmsg->unstructured->-r ../requirements.txt (line 13))
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured->-r ../requirements.txt (line 13)) (24.1.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-vision->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 5)) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r ../requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.0->effdet->unstructured[pdf]->-r ../requirements.txt (line 14)) (4.9.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (75.2.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime!=1.20.0,>=1.17.0->fastembed->-r ../requirements.txt (line 4)) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r ../requirements.txt (line 2))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.27.0->chromadb->-r ../requirements.txt (line 5)) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.20.0,>=1.17.0->fastembed->-r ../requirements.txt (line 4))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]->-r ../requirements.txt (line 14)) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->unstructured-inference>=1.1.1->unstructured[pdf]->-r ../requirements.txt (line 14)) (3.0.3)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 75.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Downloading fastembed-0.7.3-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 9.9 MB/s eta 0:00:00
# Downloading chromadb-1.3.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 114.9 MB/s eta 0:00:00
# Downloading langchain_ollama-1.0.0-py3-none-any.whl (29 kB)
# Downloading langchain_chroma-1.0.0-py3-none-any.whl (12 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.0 MB/s eta 0:00:00
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Downloading unstructured-0.18.21-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 83.4 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.9 MB/s eta 0:00:00
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 90.8 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.1 MB/s eta 0:00:00
# Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 9.9 MB/s eta 0:00:00
# Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 120.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 108.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.6 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 13.0 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 5.7 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 17.0 MB/s eta 0:00:00
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading py_rust_stemmers-0.1.5-cp312-cp312-manylinux_2_28_x86_64.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 22.6 MB/s eta 0:00:00
# Downloading pybase64-1.4.2-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.6 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.1 MB/s eta 0:00:00
# Downloading unstructured_inference-1.1.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 4.2 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 10.6 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 40.9 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_cloud_vision-3.11.0-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.1/529.1 kB 38.1 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 122.6 MB/s eta 0:00:00
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.8 MB/s eta 0:00:00
# Downloading pikepdf-10.0.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 96.4 MB/s eta 0:00:00
# Downloading pypdf-6.4.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.5/329.5 kB 25.4 MB/s eta 0:00:00
# Downloading python_iso639-2025.11.16-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 14.5 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 110.6 MB/s eta 0:00:00
# Downloading unstructured_client-0.42.4-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 17.9 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.7.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (517 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 37.8 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 10.8 MB/s eta 0:00:00
# Downloading uvloop-0.22.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 89.7 MB/s eta 0:00:00
# Downloading watchfiles-1.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (456 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 38.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 7.6 MB/s eta 0:00:00
# Downloading pypdfium2-5.1.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 103.4 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: pypika, langdetect
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=957c35be0934948b21b3b78d87333a4d4bf8377eb50b791889627838bbe00316
#   Stored in directory: /root/.cache/pip/wheels/d5/3d/69/8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=b8daf1f20e1c2b58c7dfc0928946690722dbdb51e15c0b1bcaeb965500761833
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built pypika langdetect
# Installing collected packages: tk, pypika, py-rust-stemmers, filetype, durationpy, uvloop, urllib3, unstructured.pytesseract, rapidfuzz, python-magic, python-iso639, pyproject_hooks, pypdfium2, pypdf, pybase64, pi_heif, pdf2image, opentelemetry-proto, olefile, mypy-extensions, mmh3, marshmallow, loguru, langdetect, humanfriendly, httptools, emoji, Deprecated, bcrypt, backoff, watchfiles, typing-inspect, requests, python-oxmsg, pikepdf, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnx, coloredlogs, build, posthog, pdfminer.six, opentelemetry-semantic-conventions, onnxruntime, ollama, dataclasses-json, unstructured-client, opentelemetry-sdk, kubernetes, unstructured, opentelemetry-exporter-otlp-proto-grpc, google-cloud-vision, fastembed, unstructured-inference, langchain-text-splitters, langchain-ollama, effdet, chromadb, langchain-classic, langchain-chroma, langchain-community
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.37.0
#     Uninstalling opentelemetry-proto-1.37.0:
#       Successfully uninstalled opentelemetry-proto-1.37.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.37.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.37.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.37.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.37.0
#     Uninstalling opentelemetry-api-1.37.0:
#       Successfully uninstalled opentelemetry-api-1.37.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.58b0
#     Uninstalling opentelemetry-semantic-conventions-0.58b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.58b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.37.0
#     Uninstalling opentelemetry-sdk-1.37.0:
#       Successfully uninstalled opentelemetry-sdk-1.37.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-exporter-otlp-proto-common==1.37.0, but you have opentelemetry-exporter-otlp-proto-common 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-proto==1.37.0, but you have opentelemetry-proto 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-sdk~=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# google-adk 1.19.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.38.0 which is incompatible.
# google-adk 1.19.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# Successfully installed Deprecated-1.3.1 backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 chromadb-1.3.5 coloredlogs-15.0.1 dataclasses-json-0.6.7 durationpy-0.10 effdet-0.4.1 emoji-2.15.0 fastembed-0.7.3 filetype-1.2.0 google-cloud-vision-3.11.0 httptools-0.7.1 humanfriendly-10.0 kubernetes-34.1.0 langchain-chroma-1.0.0 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-ollama-1.0.0 langchain-text-splitters-1.0.0 langdetect-1.0.9 loguru-0.7.3 marshmallow-3.26.1 mmh3-5.2.0 mypy-extensions-1.1.0 olefile-0.47 ollama-0.6.1 onnx-1.19.1 onnxruntime-1.23.2 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pdf2image-1.17.0 pdfminer.six-20251107 pi_heif-1.1.1 pikepdf-10.0.2 posthog-5.4.0 py-rust-stemmers-0.1.5 pybase64-1.4.2 pypdf-6.4.0 pypdfium2-5.1.0 pypika-0.48.9 pyproject_hooks-1.2.0 python-iso639-2025.11.16 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.14.3 requests-2.32.5 tk-0.1.0 typing-inspect-0.9.0 unstructured-0.18.21 unstructured-client-0.42.4 unstructured-inference-1.1.2 unstructured.pytesseract-0.3.15 urllib3-2.3.0 uvloop-0.22.1 watchfiles-1.1.1

# %%
# Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# In the terminal, run the following command
# ollama serve

# %%
# Choose model from link below (choose based on your machine’s power)
# https://ollama.com/library

# %%
# ollama pull MODEL_NAME
# Example:
# !ollama pull llama3:8b

# %%
# Run Program
# !python "../CLI.py"
# Out:
# 2025-11-25 12:20:05.114539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764073205.416788    1561 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764073205.498935    1561 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764073206.113302    1561 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764073206.113344    1561 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764073206.113349    1561 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764073206.113355    1561 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-25 12:20:06.171428: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model name for question generation: llama3:8b
# Model name for answer correction: llama3:8b
# /content/Question Generator/RAG.py:60: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   self.model = Ollama(model=self.model_name, base_url="http://localhost:11434", temperature =self.temperature)
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# config.json: 100% 706/706 [00:00<00:00, 3.86MB/s]
# Fetching 5 files:  20% 1/5 [00:00<00:01,  3.91it/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
#
# tokenizer_config.json: 1.24kB [00:00, 5.10MB/s]
# tokenizer.json: 711kB [00:00, 16.1MB/s]
#
# special_tokens_map.json: 100% 695/695 [00:00<00:00, 6.91MB/s]
#
# model_optimized.onnx:   0% 0.00/66.5M [00:00<?, ?B/s]
# model_optimized.onnx: 100% 66.5M/66.5M [00:00<00:00, 92.8MB/s]
# Fetching 5 files: 100% 5/5 [00:01<00:00,  4.38it/s]
#
# ===== Question Generator & Checker (CLI Mode) =====
#
# === FILE INPUT ===
# Enter file paths separated by semicolon.
# Files: NIPS-2017-attention-is-all-you-need-paper.pdf
#
# ✔ Loaded files:
#   - NIPS-2017-attention-is-all-you-need-paper.pdf
#
# === QUESTION SETTINGS ===
# Number of questions: 3
# Difficulty (Easy / Medium / Hard): easy
#
# Generating questions... please wait...
#
# === GENERATED QUESTIONS ===
#
# Question 1 (Easy): What is the primary difference between self-attention layers and recurrent layers in terms of computational complexity?
#
# Question 2 (Easy): How do the authors propose to improve computational performance for tasks involving very long sequences?
#
# Question 3 (Easy): What is the purpose of using multi-head attention in the Transformer model?
#
# === ANSWER INPUT ===
#
# Question 1 (Easy): What is the primary difference between self-attention layers and recurrent layers in terms of computational complexity?
# Your answer: In terms of  computational complexity, self-attention layers are faster than recurrent layers when the sequence  length n is smaller than the representation dimensionality d, which is most often the case with  sentence representations used by state-of-the-art models in machine translations, such as word-piece and byte-pair representations.
#
# Question 2 (Easy): How do the authors propose to improve computational performance for tasks involving very long sequences?
# Your answer: self-attention could be restricted to considering only a neighborhood of size r in the input sequence centered around the respective output position.
#
# Question 3 (Easy): What is the purpose of using multi-head attention in the Transformer model?
# Your answer: Multi-head attention allows the model to jointly attend to information from different representation  subspaces at different positions.
#
# Checking answers... please wait...
#
#
# === RESULTS ===
# Feedback for question 1:
# CORRECT
# The user's answer is correct because it accurately states that self-attention layers are faster than recurrent layers when the sequence length n is smaller than the representation dimensionality d. This is explicitly stated in the context: "In terms of computational complexity, self-attention layers are faster than recurrent layers when the sequence length n is smaller than the representation dimensionality d, which is most often the case with sentence representations used by state-of-the-art models in machine translations, such as word-piece and byte-pair representations."
#
# Sources:
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
#
#  ---------------
#
# Feedback for question 2:
# CORRECT
# The justification is that the context states "To improve computational performance for tasks involving very long sequences, self-attention could be restricted to considering only a neighborhood of size r in the input sequence centered around the respective output position." The user's answer directly addresses this idea and is supported by the provided context.
#
# Sources:
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
#
#  ---------------
#
# Feedback for question 3:
# **CORRECT**
# The user's answer directly matches what the CONTEXT states: "Multi-head attention allows the model to jointly attend to information from different representation subspaces at different positions." This is a direct quote from the context, which describes the purpose of using multi-head attention in the Transformer model.
#
# Sources:
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
# NIPS-2017-attention-is-all-you-need-paper.pdf
#
#  ---------------
#
#
# Final Score: 3 / 3
# Do you want to exit? (y/n)y
# Exiting... Goodbye!
